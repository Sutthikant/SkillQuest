# %%
from baseline_gpt import generate_prerequisites_gpt

result = generate_prerequisites_gpt("Python Programming")
print(result)
# Out:
# Here's a JSON representation of a skill tree for Python Programming, detailing the necessary subskills, their order, and their dependencies:
#
# ```json
# {
#   "skill": "Python Programming",
#   "subskills": [
#     {
#       "name": "Basic Syntax",
#       "description": "Understanding basic Python syntax, including variables, data types, and operators.",
#       "difficulty": "Easy",
#       "dependencies": [],
#       "children": [
#         {
#           "name": "Control Structures",
#           "description": "Learning about conditional statements (if, else) and loops (for, while).",
#           "difficulty": "Easy",
#           "dependencies": ["Basic Syntax"],
#           "children": [
#             {
#               "name": "Functions",
#               "description": "Understanding how to define and call functions, including parameters and return values.",
#               "difficulty": "Easy",
#               "dependencies": ["Control Structures"],
# ...

# %%
from baseline_llama import generate_prerequisites_llama

generate_prerequisites_llama("Python Programming")
# print(result)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:13<?, ?it/s]

# %%
from baseline_prompEngineering_gpt import generate_tree_promptEngineering_gpt

result = generate_tree_promptEngineering_gpt("Python Programming")
print(result)
# Out:
# Here's a JSON representation of the skill tree for Python Programming, incorporating the necessary sub-skills and their relationships:
#
# ```json
# {
#     "name": "Python Programming",
#     "children": [
#         {
#             "name": "Introduction to Python",
#             "children": [
#                 { "name": "Setting up the Environment" },
#                 { "name": "Basic Syntax" },
#                 { "name": "Data Types and Variables" },
#                 { "name": "Basic Input/Output" }
#             ]
#         },
#         {
#             "name": "Control Structures",
#             "children": [
#                 { "name": "Conditional Statements" },
#                 { "name": "Loops" },
#                 { "name": "Comprehensions" }
#             ]
#         },
#         {
#             "name": "Data Structures",
#             "children": [
#                 { "name": "Lists" },
#                 { "name": "Tuples" },
# ...
